# %%
#functions


# fuunction is a block of statement that perform a specific task 
#to make a function we use "def"
#then we give a function name 
#after this breket():
#Example--> def functionname ():

def hello():#function defination 
    print("Hello")
hello()#this is the function call 

#in function like we can give input and output 

#input-->logic-->output 
#input--> parameter of a function 
#output --> return
# Out:
# Hello

# %%
#example
def sum(a,b):#parameter and a and b there are a placeholder 
    s = a + b
    return s

#function call 
ans = sum(3,4)
print(ans)
# Out:
# 7
