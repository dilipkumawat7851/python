# %%
#continue case 
i = 1
while (i<=10):
    if(i%3==0):
        i+=1
        continue 
    print(i)
    i += 1
    print("Outside loop:")
# Out:
# 1
# Outside loop:
# 2
# Outside loop:
# 4
# Outside loop:
# 5
# Outside loop:
# 7
# Outside loop:
# 8
# Outside loop:
# 10
# Outside loop:

# %%
#print all the odd no from 1 to 10 

i = 1
while(i<=10):
    if(i%2==1):

# %%
#for loop
#for loop-->sequential travessal

string = "hello"
#in = membership  operator 
for var in string:
    print(var)
# Out:
# h
# e
# l
# l
# o

# %%
string = "hello"
