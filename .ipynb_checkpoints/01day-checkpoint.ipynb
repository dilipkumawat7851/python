# %%
#operator precedence -> priority
# if any presedence has same then we follow left to right 
10/2*3

# ()
# **
# *,/,%
# +,-
# ==,!=,>,>=,<,<=
# not
# and
# or
# Out:
# 15.0

# %%
# type conversion-->it has two types 
# 1.type conversion, 2.casting
# type conversion like implicit->python automatic hota h 
a=4
b=4
print(type(a/5))
# Out:
# <class 'float'>

# %%
ans=(5+10.0)#type conversion 
print(type(ans))
# Out:
# <class 'float'>

# %%
# 2.type casting 
# it was doing by developer (explicit type casting like it is not done by python automatic 
ans=int(5+11.1)
print(type(ans))
# Out:
# <class 'int'>

# %%
val=bool(-123)
print(val,type(val))#true is non zero and flase is basically 0 value
# Out:
# True <class 'bool'>

# %%
#user input

a = input("Enter a value:")
print(a)
# Out:
# Enter a value: hiii
# hiii

# %%
a = input("Enter your name :")
print("Welcome" , a)
# Out:
# Enter your name : manish
# Welcome manish

# %%
#concatenation --> sum = "10"+"2"

# %%
a = input("Enter a no ")
b = input("Enter second no ")

sum = a + b

print(sum)

#it was called a concatenation
# Out:
# Enter a no  3
# Enter second no  4
# 34

# %%
a = int(input("Enter a no "))
b = int(input("Enter second no "))

sum = a + b

print(sum)
# Out:
# Enter a no  2
# Enter second no  3
# 5

# %%
#print the avg of 2 no 

a = float(input("Enter a first no :"))
b = float(input("Enter a second no :"))

avg = (a+b)/2
print("the avg is ",avg)
# Out:
# Enter a first no : 2
# Enter a second no : 3
# the avg is  2.5

# %%
#Assignment 1

# %%
#WAP that ask a user for their name and age 
name = input("Enter your name:")
age =  input ("Enter your age:")

print("hello",name, "you are ",age)
# Out:
# Enter your name: dilip
# Enter your age: 18
# hello dilip you are  18

# %%
#Take two no and do add , diff , multi, divide 

a = float(input("Enter a no :"))
b = float(input("Enter a 2nd no:"))
add=a+b
diff=a-b
multi=a*b
divi=a/b

print(add)
print(diff)
print(multi)
print(divi)
# Out:
# Enter a no : 3
# Enter a 2nd no: 6
# 9.0
# -3.0
# 18.0
# 0.5

# %%
#ask the user to enter two integer and one float , Convert them all to float and print their avrage

a = int(input("Enter a no :"))
b = int(input("Enter a 2nd no:"))
c = float(input("Enter a 3nd no:"))

avg=(a+b+c)/3

print(avg)
print(type(avg))
# Out:
# Enter a no : 1
# Enter a 2nd no: 2
# Enter a 3nd no: 3.6
# 2.1999999999999997
# <class 'float'>

# %%
#the user enter a string containing a number e.g-> "45" convert it in int, float, string a

a = str(input("Enter a string:"))

a = int(a)
print(type(a))
a = str(a)
print(type(a))
a = float(a)
print(type(a))
# Out:
# Enter a string: 7
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
#Evaluate
x = 10 + 3 * 2**2
print(x)
# Out:
# 22
